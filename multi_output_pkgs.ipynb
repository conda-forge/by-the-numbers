# %%
import requests
from functools import lru_cache
from collections import defaultdict, Counter
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor
import json

# %%
FILE_LISTING = requests.get('https://raw.githubusercontent.com/regro/libcfgraph/master/.file_listing.json').json()
# TODO: upstream this to libcfgraph so we just request it, so we reduce bandwidth requirements
ARTIFACT_TO_PKG = {v.split('/')[-1].rsplit('.', 1)[0]: v.split('/')[1] for v in FILE_LISTING}

# %%
sub_listing = [f.split('/')[-1].split('.')[0] for f in FILE_LISTING if 'import_maps/' in f]

# %% [raw]
# hubs_auths = requests.get(
#     'https://raw.githubusercontent.com/regro/cf-graph-countyfair/master/ranked_hubs_authorities.json').json()

# %%
import json
hubs_auths = json.load(open('/home/christopher/dev/conda-forge/cf-graph-countyfair/ranked_hubs_authorities.json'))

# %%
import string
alpha = string.ascii_lowercase

# %%
@lru_cache()
def _import_map_cache(import_first_two_letters):
    url = f'https://raw.githubusercontent.com/regro/libcfgraph/master/import_maps/{import_first_two_letters}.json'.lower()
    return {k: set(v['elements']) for k, v in requests.get(url).json().items()}

# %%
def extract_pkg_from_import(name):
    ftl = name[:2]
    import_map = _import_map_cache(ftl)
    supplying_artifacts = import_map[name]
    import_to_artifact = {name: supplying_artifacts}
    supplying_pkgs = {ARTIFACT_TO_PKG[k] for k in supplying_artifacts}
    import_to_pkg = {name: supplying_pkgs}
    pkgs_to_artifacts = defaultdict(set)
    for a in supplying_artifacts:
        pkgs_to_artifacts[ARTIFACT_TO_PKG[a]].add(a)
    import_to_pkg_to_artifact = {name: pkgs_to_artifacts}

    return next(iter(k for k in hubs_auths if k in supplying_pkgs), None), import_to_artifact, import_to_pkg, import_to_pkg_to_artifact

# %%
multi_defined_pkgs = defaultdict(set)
clobbered_imports = set()

# %%
for import_map_name in tqdm(sub_listing):
    for import_name in _import_map_cache(import_map_name.lower()):
        if any(import_name.startswith(k) for k in ['tests.', 'test.', 'examples.', 'example.']):
            continue
        best, i_to_arts, i_to_pkgs, import_to_pkg_to_artifact = extract_pkg_from_import(import_name)
        if not best:
            continue
        pkgs = set().union(*[v for k, v in import_to_pkg_to_artifact[import_name].items() if k != best])
        if pkgs:
            multi_defined_pkgs[best].update(pkgs)
            clobbered_imports.add(import_name)
# Out:
# 100%|██████████| 513/513 [03:30<00:00,  2.44it/s]

# %%
len(clobbered_imports)
# Out:
# 16611

# %%
len(multi_defined_pkgs)
# Out:
# 385

# %%
[(a, len(multi_defined_pkgs[a])) for a in sorted(multi_defined_pkgs, key=lambda x: len(multi_defined_pkgs[x]))]
# Out:
# [('mistune', 1),
#  ('cached-property', 1),
#  ('dbfread', 1),
#  ('sk-video', 1),
#  ('labjackpython', 1),
#  ('regex', 1),
#  ('defusedxml', 1),
#  ('pyexcel-io', 1),
#  ('prettytable', 1),
#  ('privy', 1),
#  ('progressbar', 1),
#  ('prometheus_client', 1),
#  ('dropbox', 1),
#  ('intake-accumulo', 1),
#  ('yodatools', 1),
#  ('extras', 1),
#  ('block_tracing', 1),
#  ('python-gnupg', 1),
#  ('creoleparser', 1),
#  ('jeepney', 1),
#  ('ipython', 1),
#  ('ipykernel', 1),
#  ('ipywidgets', 1),
#  ('python-magic', 1),
#  ('pysocks', 1),
#  ('keyring', 1),
#  ('keyrings.alt', 1),
#  ('futures', 1),
#  ('python-coreapi', 1),
#  ('coreschema', 1),
#  ('flatten_json', 1),
#  ('aiida-core', 1),
#  ('ruamel', 1),
#  ('nbconvert', 1),
#  ('nbformat', 1),
#  ('argo-workflows', 1),
#  ('sherlockml-boltzmannclean', 1),
#  ('pickleshare', 1),
#  ('diffpy.structure', 1),
#  ('widgetsnbextension', 1),
#  ('lml', 1),
#  ('shapely', 1),
#  ('hdijupyterutils', 1),
#  ('wcwidth', 1),
#  ('secretstorage', 1),
#  ('send2trash', 1),
#  ('sentry-sdk', 1),
#  ('et_xmlfile', 1),
#  ('sat-search', 1),
#  ('python-jose', 1),
#  ('genshi', 1),
#  ('ligo-common', 1),
#  ('temporal-cache', 1),
#  ('terminado', 1),
#  ('testpath', 1),
#  ('scandir', 1),
#  ('pexpect', 1),
#  ('simplegeneric', 1),
#  ('singledispatch', 1),
#  ('qtconsole', 1),
#  ('pandas', 1),
#  ('pandocfilters', 1),
#  ('pathlib2', 1),
#  ('python-ldap', 1),
#  ('async-timeout', 1),
#  ('pbr', 1),
#  ('funcsigs', 1),
#  ('nose_parameterized', 1),
#  ('notebook', 1),
#  ('ptyprocess', 1),
#  ('jupyter_console', 1),
#  ('jupyterlab-latex', 1),
#  ('evalml-core', 1),
#  ('mock', 1),
#  ('freecad', 2),
#  ('reuse', 2),
#  ('rdflib', 2),
#  ('py', 2),
#  ('pycparser', 2),
#  ('pyct', 2),
#  ('pytest', 2),
#  ('tvb-library', 2),
#  ('progressbar2', 2),
#  ('pdb2pqr_htmd_propka30', 2),
#  ('entrypoints', 2),
#  ('starlette', 2),
#  ('cryptography', 2),
#  ('flask-cors', 2),
#  ('flask-restful', 2),
#  ('flask-security', 2),
#  ('flask-sqlalchemy', 2),
#  ('mysqlclient', 2),
#  ('cockroachdb', 2),
#  ('colorama', 2),
#  ('userspacefs', 2),
#  ('xdg', 2),
#  ('suds-jurko', 2),
#  ('aniso8601', 2),
#  ('pyjnius', 2),
#  ('lxml', 2),
#  ('json-rpc', 2),
#  ('pluggy', 2),
#  ('pandas_flavor', 2),
#  ('asn1crypto', 2),
#  ('aspy.yaml', 2),
#  ('kim_edn', 2),
#  ('python3-openid', 2),
#  ('openquake.engine', 2),
#  ('opt_einsum', 2),
#  ('pysmbclient', 2),
#  ('poetry', 2),
#  ('billiard', 2),
#  ('appdirs', 2),
#  ('atom', 2),
#  ('email_validator', 2),
#  ('cffi', 2),
#  ('yaqd-control', 2),
#  ('more-itertools', 2),
#  ('typing_extensions', 3),
#  ('typing_inspect', 3),
#  ('decorator', 3),
#  ('xmlrunner', 3),
#  ('pymsgbox', 3),
#  ('libsass', 3),
#  ('pyscreeze', 3),
#  ('pytweening', 3),
#  ('proto-plus', 3),
#  ('backports.tempfile', 3),
#  ('backports.weakref', 3),
#  ('flask-assets', 3),
#  ('flask-redis', 3),
#  ('flask-turbolinks', 3),
#  ('ipython_genutils', 3),
#  ('dataclasses', 3),
#  ('datapackage', 3),
#  ('python-dateutil', 3),
#  ('mypy_extensions', 3),
#  ('pyzmq', 3),
#  ('conda', 3),
#  ('neo4j-python-driver', 3),
#  ('webassets', 3),
#  ('tornado', 3),
#  ('click_config_file', 3),
#  ('clickhouse-driver', 3),
#  ('ansible', 3),
#  ('seaborn', 3),
#  ('cmake_format', 3),
#  ('genesis-pyapi', 3),
#  ('geojsonio', 3),
#  ('libcst', 3),
#  ('jsmin', 3),
#  ('plotly', 3),
#  ('sphinxbase', 3),
#  ('dataspyre', 3),
#  ('signac', 3),
#  ('grpcio', 3),
#  ('ogh', 3),
#  ('pathlib', 3),
#  ('kim_property', 3),
#  ('pocketsphinx', 3),
#  ('nose', 3),
#  ('google-auth', 3),
#  ('attrs', 3),
#  ('jupyter_client', 3),
#  ('jupyter_core', 3),
#  ('traitlets', 3),
#  ('pyyaml', 3),
#  ('drmaa', 4),
#  ('django-storages', 4),
#  ('blinker', 4),
#  ('python-editor', 4),
#  ('marshmallow', 4),
#  ('win_unicode_console', 4),
#  ('pillow', 4),
#  ('setuptools-markdown', 4),
#  ('tzdata', 4),
#  ('ros-genpy', 4),
#  ('nidaqmx-python', 4),
#  ('pylons', 4),
#  ('python-cufflinks', 4),
#  ('tomopy', 4),
#  ('vispy', 4),
#  ('nvidia-ml', 5),
#  ('enum34', 5),
#  ('tableschema', 5),
#  ('jsonschema', 5),
#  ('python-spake2', 5),
#  ('scipy', 5),
#  ('ez_setup', 5),
#  ('pyexcel-ezodf', 5),
#  ('smmap', 5),
#  ('azure-cli-telemetry', 5),
#  ('yarn-api-client', 5),
#  ('pdfminer.six', 6),
#  ('netcdf4', 6),
#  ('ruamel.yaml', 6),
#  ('pint', 6),
#  ('setuptools_scm', 6),
#  ('dftbplus-python', 6),
#  ('lalxml', 6),
#  ('configobj', 7),
#  ('magics', 7),
#  ('ioos_tools', 7),
#  ('metaphone', 7),
#  ('prompt_toolkit', 8),
#  ('jieba3k', 8),
#  ('bleach', 8),
#  ('python-crontab', 8),
#  ('pesummary', 8),
#  ('hydra-core', 8),
#  ('fabric', 8),
#  ('build_capi', 8),
#  ('uritemplate', 8),
#  ('requests_cache', 9),
#  ('python-javapackages-cos7-aarch64', 9),
#  ('dask_labextension', 9),
#  ('semver', 9),
#  ('dvc', 9),
#  ('protobuf', 9),
#  ('azure-mgmt-resource', 9),
#  ('itsdangerous', 10),
#  ('datreant', 10),
#  ('werkzeug', 10),
#  ('nionutils', 10),
#  ('xcb-proto', 10),
#  ('pandera-core', 10),
#  ('jinja2', 11),
#  ('markupsafe', 11),
#  ('easybuild-framework', 11),
#  ('click', 11),
#  ('tabulator', 11),
#  ('geoviews', 11),
#  ('azure-storage', 11),
#  ('prov', 12),
#  ('pytz', 12),
#  ('nr.types', 12),
#  ('pyamg', 12),
#  ('mercurial', 12),
#  ('arm_pyart', 13),
#  ('flask', 13),
#  ('pymongo', 13),
#  ('pyrad_mch', 14),
#  ('gdown', 14),
#  ('configs', 14),
#  ('sqlalchemy', 14),
#  ('opencensus', 14),
#  ('brent-search', 14),
#  ('requests', 15),
#  ('orange3', 15),
#  ('bgen-reader', 15),
#  ('path.py', 15),
#  ('cdms2', 16),
#  ('astro-gala', 16),
#  ('gitdb2', 16),
#  ('mkdocs-material', 16),
#  ('nest-simulator', 16),
#  ('biorbd', 16),
#  ('genutil', 16),
#  ('cdat_info', 16),
#  ('cdutil', 16),
#  ('advbumpversion', 16),
#  ('urllib3', 16),
#  ('portalocker', 16),
#  ('locustio', 17),
#  ('dagster_ge', 17),
#  ('versioneer', 17),
#  ('colour', 17),
#  ('lit', 17),
#  ('bumpversion', 17),
#  ('foamalgo', 18),
#  ('python-slugify', 18),
#  ('simhash', 18),
#  ('dagster_bash', 19),
#  ('azure-cosmos', 19),
#  ('ds-lime', 19),
#  ('xtb', 19),
#  ('cppcolormap', 19),
#  ('ephem', 19),
#  ('camb', 20),
#  ('coveralls', 20),
#  ('thrift', 20),
#  ('openpyxl', 20),
#  ('dagster_aws', 21),
#  ('vaex-ui', 21),
#  ('faker', 21),
#  ('trio-asyncio', 21),
#  ('pyreadline', 22),
#  ('autovizwidget', 22),
#  ('future', 23),
#  ('fmpy', 23),
#  ('incremental', 24),
#  ('dagster_gcp', 24),
#  ('pynvim', 24),
#  ('qcfractal', 24),
#  ('vaex-core', 24),
#  ('spleeter-gpu', 24),
#  ('twisted', 24),
#  ('django-guardian', 26),
#  ('s_gd2', 26),
#  ('pygpu', 27),
#  ('jaraco.functools', 27),
#  ('aliyun-python-sdk-core', 28),
#  ('quilt', 28),
#  ('pipenv', 29),
#  ('javabridge', 30),
#  ('rust', 30),
#  ('dagster_dbt', 32),
#  ('filesystem-spec', 32),
#  ('google-cloud-bigquery-storage', 32),
#  ('ufal.udpipe', 33),
#  ('python-libsbml', 34),
#  ('asap', 34),
#  ('pyfai', 35),
#  ('acorns', 35),
#  ('python-eccodes', 37),
#  ('jupyter-sphinx', 38),
#  ('glue-core', 39),
#  ('importlib_metadata', 41),
#  ('jupyterhub', 41),
#  ('ndarray_listener', 42),
#  ('dagster_snowflake', 43),
#  ('awkward', 44),
#  ('knit', 45),
#  ('dagster_cron', 48),
#  ('dagster_dask', 48),
#  ('dagster_datadog', 48),
#  ('dagster_pagerduty', 48),
#  ('dagster_pandas', 48),
#  ('dagster_papertrail', 48),
#  ('dagster_postgres', 48),
#  ('dagster_slack', 48),
#  ('dagster_spark', 48),
#  ('dagster_ssh', 48),
#  ('dagster_twilio', 48),
#  ('tensorflow', 48),
#  ('box2d-py', 49),
#  ('configparser', 53),
#  ('batman-package', 54),
#  ('six', 56),
#  ('xgboost', 58),
#  ('theano', 58),
#  ('cmt', 59),
#  ('azure-storage-blob', 62),
#  ('pre-commit', 63),
#  ('eo-learn-core', 68),
#  ('primesieve', 70),
#  ('pypng', 70),
#  ('dask', 74),
#  ('jupyter', 74),
#  ('iris', 75),
#  ('silx', 76),
#  ('numpy_sugar', 76),
#  ('cf_units', 78),
#  ('google-cloud-bigquery', 79),
#  ('brotlipy', 82),
#  ('pycryptodome', 83),
#  ('numpy', 83),
#  ('geometric_features', 83),
#  ('dagster_graphql', 89),
#  ('argon2_cffi', 90),
#  ('lalframe', 91),
#  ('lalmetaio', 97),
#  ('black', 98),
#  ('hyperspy', 103),
#  ('keras', 103),
#  ('dateparser', 120),
#  ('fenics', 126),
#  ('lscsoft-glue', 128),
#  ('lalsimulation', 153),
#  ('spacy', 165),
#  ('pyqt', 170),
#  ('uproot', 192),
#  ('parmed', 213),
#  ('scikit-bio', 217),
#  ('pyarrow', 236),
#  ('cvxpy', 266),
#  ('ambertools', 283),
#  ('google-api-core', 296),
#  ('lal', 300),
#  ('root', 309),
#  ('vtk', 355),
#  ('datashader', 428),
#  ('matplotlib', 587),
#  ('pyproj', 742),
#  ('pygments', 2206)]

# %%
dict(multi_defined_pkgs)

# %%
c = Counter([k.split('.')[0] for k in clobbered_imports])

# %%
c.most_common(10)
# Out:
# [('tensorflow', 2109),
#  ('openquake', 804),
#  ('pandas', 608),
#  ('scipy', 577),
#  ('silx', 565),
#  ('numpy', 433),
#  ('glue', 371),
#  ('ansible', 363),
#  ('theano', 347),
#  ('hyperspy', 327)]

# %%
multi_defined_pkgs['pandas']
# Out:
# {'autovizwidget-0.12.6-py_1000'}

# %%
multi_defined_pkgs['pygments']
# Out:
# {'labelme-3.16.1-py37h47b7e1a_0',
#  'pyproprop-0.4.1-py_0',
#  'pyrobuf-0.9.0-py36h4a8c4bd_0',
#  'ffx-1.3.4-py35_0',
#  'trio_asyncio-0.11.0-py37hc8dfbb8_0',
#  'pycroscopy-0.60.0-py27_0',
#  'pyrobuf-0.8.5-py37h0a44026_1000',
#  'plasmaboundaries-0.1.4-pyh9f0ad1d_0',
#  'optuna-1.4.0-py_0',
#  'pybtex-0.22.2-py37_0',
#  'pyrobuf-0.9.0-py27h4a8c4bd_0',
#  'andes-1.0.4-py37hc8dfbb8_0',
#  'deepforest-0.3.0-py38hc84c608_0',
#  'landlab-2.0.0b5-py36hc8d92b1_0',
#  'fasttsne-0.2.7-py36h7eb728f_1',
#  'yt_astro_analysis-1.0.0-py39h49efd1d_1001',
#  'point_cloud_utils-0.13.0-py36hbf1eeb5_0',
#  'cmreshandler-1.0.0-py36_0',
#  'terrainbento-1.0.0-py_0',
#  'otwrapy-0.7-py35_1',
#  'xsum-1.1.1-py39h86d69c3_2',
#  'otwrapy-0.9-pyh3d53f50_2',
#  'pyrobuf-0.9.0-py37h6de7cb9_0',
#  'pykafka-2.8.0-py38h43c8af4_1001',
#  'igl-0.3-py36hd0167a9_0',
#  'bamnostic-1.0.4-py_0',
#  'pyrobuf-0.9.3-py36h831f99a_1',
#  'pfapack-0.2.1-py36hc4c5385_0',
#  'jaws-0.6.2-py37_0',
#  'polyfempy-0.2.1-py37h6538335_1',
#  'trio-asyncio-0.10.0-py37_0',
#  'igl-0.3.1-py36h6dc7ae4_0',
#  'pykafka-2.7.0-py35h8ab9f6a_0',
#  'point_cloud_utils-0.13.0-py37h96a391d_0',
#  'landlab-2.2.0-py36h642477c_1',
#  'quickle-0.2.0-py38h4d0b108_0',
#  'igl-0.1-py37hd0167a9_1',
#  'pyusid-0.0.7-py27_1',
#  'pybtex-0.22.2-py36hc560c46_2',
#  'yt_astro_analysis-1.0.0-py27h0c8e037_1000',
#  'landlab-2.0.0b5-py36h3b54f70_0',
#  'emperor-1.0.1-py37hf985489_1',
#  'lifelines-0.21.0-py_0',
#  'pytmc-2.6.7-py_0',
#  'suds-jurko-0.6-py37_1001',
#  'magpylib-1.1.0b0-py_0',
#  'pykafka-2.8.0-py38hfa6e2cd_1000',
#  'andes-0.8.4-py37hc8dfbb8_0',
#  'pyrobuf-0.9.1-py36h0130604_0',
#  'clisops-0.3.1-py38h32f6830_0',
#  'pyproprop-0.4.0-py_0',
#  'arosics-1.0.0-py36h9f0ad1d_0',
#  'airflow-1.8.0-py35_1',
#  'igl-0.4.1-py37h6dc7ae4_0',
#  'superset-0.34.0rc1-py36_0',
#  'pycroscopy-0.60.2-py36_0',
#  'jaws-1.0-py27_1',
#  'jaws-0.7.7-py27_0',
#  'aiida-core-1.2.1-py37hc8dfbb8_1',
#  'arosics-0.9.24-py36h9f0ad1d_1',
#  'lifelines-0.22.8-py_0',
#  'bqplot-0.12.7-pyh9f0ad1d_0',
#  'point_cloud_utils-0.11.0-py36h9de70de_0',
#  'polyfempy-0.2.1-py37hf484d3e_1',
#  'point_cloud_utils-0.12.1-py36h96a391d_0',
#  'xsum-1.1.1-py36h499bf3f_1',
#  'jaws-0.8.1-py36_0',
#  'jupyter_server-1.0.4-py37hc8dfbb8_0',
#  'pykafka-2.7.0-py36_0',
#  'ipygany-0.4.0-py_0',
#  'point_cloud_utils-0.12.2-py37h9de70de_0',
#  'landlab-2.0.0b5-py38hc8d92b1_0',
#  'yt_astro_analysis-1.0.0-py37h3a3b6f7_1001',
#  'andes-0.8.3-py36h9f0ad1d_0',
#  'deepforest-0.3.2-py37h570ac47_0',
#  'point_cloud_utils-0.12.2-py36h96a391d_0',
#  'jaws-0.7-py37_0',
#  'ipywebrtc-0.4.3-py27_1000',
#  'pyusid-0.0.6.1-py37_1',
#  'pybtex-0.22.2-py38h32f6830_1',
#  'pymapd-0.19.0-py_0',
#  'tomlkit-0.5.7-py37_0',
#  'fasttsne-0.2.11-py36h452e1ab_0',
#  'bqplot-0.12.13-pyh9f0ad1d_0',
#  'neptune-client-0.4.111-pyh9f0ad1d_0',
#  'suspect-0.4.3-py36h5dafb3c_1',
#  'theano-pymc-1.0.10-py38hadf7658_0',
#  'igl-0.3.1-py37hd0167a9_0',
#  'clisops-0.2.0-py37hc8dfbb8_0',
#  'stitchm-1.0.1-py36h9f0ad1d_2',
#  'igl-2.2.1-py36hb1c73a4_0',
#  'point_cloud_utils-0.11.0-py37hbf1eeb5_0',
#  'ioos_qc-1.0.0-pyh9f0ad1d_0',
#  'point_cloud_utils-0.13.0-py38hd103949_2',
#  'aiida-core-1.2.1-py36h9f0ad1d_0',
#  'theano-pymc-1.0.9-py36h003fed8_0',
#  'suspect-0.4.3-py38h50d1736_1',
#  'andes-1.2.0-py36h9f0ad1d_0',
#  'pyusid-0.0.8.1-pyh9f0ad1d_0',
#  'landlab-2.2.0-py38h1e00858_0',
#  'pykafka-2.8.0-py37h36adfd1_1000',
#  'pyrobuf-0.9.1-py38h950e882_0',
#  'jaws-0.3.2-py_0',
#  'pylama-7.6.6-py_0',
#  'trio_asyncio-0.11.0-py38h32f6830_2',
#  'point_cloud_utils-0.9.2-py37hbf1eeb5_0',
#  'stitchm-1.0.3-py39hde42818_1',
#  'thredds_crawler-1.4.0-py27_0',
#  'trio_asyncio-0.11.0-py38h32f6830_0',
#  'aiida-core-1.2.1-py38h32f6830_0',
#  'polyfempy-0.2.1-py36h0a44026_0',
#  'pyrobuf-0.8.6-py36h0a44026_0',
#  'quilt3-3.1.14-pyh9f0ad1d_2',
#  'point_cloud_utils-0.16.0-py38h89463c3_0',
#  'jaws-0.9.1-py37_0',
#  'aws-parallelcluster-2.3.2a1-py36_0',
#  'bamnostic-0.8.4-py_0',
#  'point_cloud_utils-0.10.1-py27hbf1eeb5_0',
#  'xsum-1.1.1-py36hdb11119_2',
#  'point_cloud_utils-0.12.2-py38hbf1eeb5_0',
#  'jupytext-0.8.5-0',
#  'point_cloud_utils-0.13.0-py38h96a391d_1',
#  'jaws-0.7.4-py27_0',
#  'pykafka-2.8.0-py37h854ab63_1001',
#  'clisops-0.3.1-pyh9f0ad1d_1',
#  'thredds_crawler-1.2.0-py35_0',
#  'landlab-2.0.0b3-py38h3b54f70_0',
#  'verta-0.15.4-pyh9f0ad1d_0',
#  'landlab-2.0.1-py38h65ad66c_0',
#  'airflow-1.8.0-py27_2',
#  'pyrobuf-0.9.0-py38h6538335_0',
#  'igl-0.2-py36h6dc7ae4_0',
#  'neptune-client-0.4.116-pyh9f0ad1d_0',
#  'neptune-client-0.4.100-py_0',
#  'landlab-2.0.0b5-py37h3b54f70_0',
#  'jaws-0.4.5-py27_0',
#  'point_cloud_utils-0.11.0-py37h96a391d_1',
#  'igl-0.4.1-py37hd0167a9_0',
#  'quickle-0.2.0-py39hb5aae12_0',
#  'landlab-2.0.0b4-py36hc1659b7_0',
#  'jupyter_server-1.0.4-py37hc8dfbb8_1',
#  'igl-0.3-py36h6dc7ae4_0',
#  'pystac-0.5.1-pyh9f0ad1d_0',
#  'point_cloud_utils-0.10.1-py38hbf1eeb5_0',
#  'andes-1.1.4-py38h32f6830_0',
#  'portalocker-1.4.0-py36_1',
#  'quilt3-3.1.7-py37_0',
#  'neutronics_material_maker-0.1.9-py_0',
#  'suspect-0.4.3-py39h6e9494a_1',
#  'landlab-2.0.0b6-py38hc8d92b1_0',
#  'tomlkit-0.5.11-py38h32f6830_1',
#  'scikit-lego-0.5.2-py_0',
#  'pyrobuf-0.9.0-py37h6538335_0',
#  'fasttsne-0.2.13-py36h452e1ab_0',
#  'jaws-0.7.6-py36_0',
#  'kim-edn-1.2.0-py_0',
#  'andes-1.2.0-py37hc8dfbb8_0',
#  'neutronics_material_maker-0.1.8-py_0',
#  'jaws-0.9.2-py36_0',
#  'quickle-0.1.0-py38h1e8a9f7_1',
#  'nbsmoke-0.5.0-pyh9f0ad1d_0',
#  'pyrobuf-0.9.3-py39hf149a3a_1',
#  'yt_astro_analysis-1.0.0-py36hfa6e2cd_0',
#  'yt_astro_analysis-1.0.0-py36h1de35cc_1000',
#  'andes-1.1.3-py38h32f6830_0',
#  'point_cloud_utils-0.11.0-py36hbf1eeb5_1',
#  'pybtex-0.22.2-py36h9f0ad1d_2',
#  'polyfempy-0.2.2-py36h0a44026_0',
#  'xsum-1.1.1-py37hb449ec0_2',
#  'grayskull-0.2.4-py_0',
#  'igl-0.4.1-py38h6dc7ae4_0',
#  'spectate-0.4.1-pyh9f0ad1d_0',
#  'pykafka-2.8.0-py36hba13f1d_1000',
#  'andes-1.1.3-py37hc8dfbb8_0',
#  'quickle-0.3.0-py39h07f9747_0',
#  'intake-astro-0.1.1-py_0',
#  'oddt-0.7-pyh500f238_0',
#  'fasttsne-0.2.6-py35h452e1ab_0',
#  'ipywebrtc-0.4.1-py37_1001',
#  'cmreshandler-1.0.0-py36hc560c46_1',
#  'point_cloud_utils-0.12.1-py38hbf1eeb5_0',
#  'pyathena-1.5.0-py36_0',
#  'neptune-client-0.4.106-py_0',
#  'crystals-0.6.3-py_1',
#  'andes-1.2.1-py_1',
#  'quilt3-3.1.12-py36h9f0ad1d_0',
#  'polyfempy-0.2-py37h6538335_1',
#  'polyfempy-0.2-py36h6538335_1',
#  'google-cloud-bigquery-0.24.0-py35_0',
#  'verta-0.14.3-pyh9f0ad1d_0',
#  'igl-0.3-py37h6dc7ae4_0',
#  'tomlkit-0.5.8-py37_0',
#  'pyrobuf-0.9.3-py38h11c0d25_1',
#  'tsfresh-0.12.0-py_0',
#  'point_cloud_utils-0.9.2-py36h96a391d_0',
#  'jaws-0.8.2-py36_0',
#  'django-controlcenter-0.2.8-py_0',
#  'pyrobuf-0.9.0-py36hbd05846_1',
#  'igl-2.2.1-py36h175514a_1',
#  'quickle-0.1.0-py39hb5aae12_1',
#  'scikit-lego-0.6.2-pyhd8ed1ab_0',
#  'point_cloud_utils-0.15.1-py36h1f35d00_2',
#  'moviepy-0.2.3.3-py35_0',
#  'saws-0.4.3-py37_1',
#  'point_cloud_utils-0.10.1-py37h9de70de_1',
#  'andes-1.0.8-py38h32f6830_0',
#  'igl-0.3.1-py36h3084ebe_0',
#  'quilt3-3.0.6-py37_1',
#  'yarg-0.1.9-py34_0',
#  'quickle-0.4.0-py38h4d0b108_0',
#  'fasttsne-0.2.13-py37h7eb728f_1',
#  'pyrobuf-0.8.5-py27hc56fc5f_1000',
#  'jaws-0.5-py36_0',
#  'qme-0.0.11-py_0',
#  'pyrobuf-0.8.7-py37he1b5a44_0',
#  'optuna-2.3.0-pyhd8ed1ab_0',
#  'greedy-0.1.0-py_0',
#  'tomlkit-0.5.5-py36_0',
#  'tomlkit-0.5.4-py36_0',
#  'bamnostic-1.0.0-py_0',
#  'tomlkit-0.7.0-py38h32f6830_1',
#  'igl-2.2.1-py36h9597fa9_1',
#  'ibm_db-3.0.2-py36h37b9a7d_0',
#  'pymapd-0.20.0-py_0',
#  'trio_asyncio-0.10.0-py36_1003',
#  'otwrapy-0.7-py36_0',
#  'andes-0.8.2-py36_0',
#  'grayskull-0.2.0-py_0',
#  'cyberpandas-1.1.1-py36hc560c46_1001',
#  'landlab-2.2.0-py37h57c32b8_0',
#  'polyfempy-0.0.1-py36h0a44026_0',
#  'xsum-1.1.1-py38h95a2b95_2',
#  'cyberpandas-1.1.1-py27_0',
#  'neptune-client-0.4.123-pyh9f0ad1d_0',
#  'deepforest-0.3.2-py36h831f99a_1',
#  'andes-1.2.1-py38h32f6830_0',
#  'neptune-client-0.4.121-pyh9f0ad1d_0',
#  'pycroscopy-0.60.4-py36_0',
#  'google-cloud-bigquery-0.24.0-py36_0',
#  'jaws-0.7.7-py37_1',
#  'deepforest-0.3.2-py37h570ac47_2',
#  'yt_astro_analysis-1.0.0-py27h0c8e037_0',
#  'neptune-client-0.4.99-py_0',
#  'ghost.py-0.2.3-py35_0',
#  'cyberpandas-1.1.1-py36hc560c46_1002',
#  'jaws-1.0-py36_1',
#  'point_cloud_utils-0.10.1-py27hbf1eeb5_1',
#  'jaws-0.4.8-py27_0',
#  'json5-0.9.0-py_0',
#  'aiida-core-1.2.1-py38h32f6830_1',
#  'bqplot-0.12.2-py_0',
#  'crystals-0.6.3-py_0',
#  'point_cloud_utils-0.12.2-py38h9de70de_0',
#  'igl-0.5-py37h22065cd_0',
#  'andes-1.1.1-py38h32f6830_0',
#  'pykafka-2.6.0-py36_0',
#  'polyfempy-0.2.3-py36h6538335_0',
#  'emperor-1.0.0b19-py37_0',
#  'hydra-core-0.11.3-py_0',
#  'plonk-0.6.2-py_0',
#  'pyrobuf-0.8.5-py36h6538335_1000',
#  'pykafka-2.8.0-py36h40d68c1_1000',
#  'igl-0.4-py36hd0167a9_1',
#  'stitchm-1.0.2-py36h9f0ad1d_0',
#  'emperor-1.0.0-py36_0',
#  'pybtex-0.22.2-py36h9f0ad1d_1',
#  'pyrobuf-0.9.0-py27haf22ab1_1',
#  'pyrobuf-0.9.1-py36h90709c0_0',
#  'theano-pymc-1.0.9-py36hf8241e8_0',
#  'pycroscopy-0.60.6-py36h9f0ad1d_0',
#  'landlab-2.0.0b6-py38h3b54f70_0',
#  'grayskull-0.4.0-py_0',
#  'quilt3-3.1.8-py36_0',
#  'pykafka-2.8.0-py39h4cdbadb_1002',
#  'intake-geopandas-0.2.4-pyhd8ed1ab_0',
#  'tomlkit-0.5.7-py36_0',
#  'emperor-1.0.1-py37h89c1867_1',
#  'suspect-0.4.3-py38h32f6830_0',
#  'grayskull-0.5.1-py_0',
#  'suds-jurko-0.6-py36hc560c46_1002',
#  'aws-parallelcluster-2.3.2a1-py27_1',
#  'point_cloud_utils-0.12.2-py38h96a391d_0',
#  'pyusid-0.0.6.3-py36_0',
#  'stitchm-1.0.1-py36hc560c46_1',
#  'ibm_db-3.0.1-py27h516909a_0',
#  'jaws-0.3.3-py_0',
#  'andes-1.1.2-py37hc8dfbb8_0',
#  'quickle-0.1.0-py38h4d0b108_0',
#  'fasttsne-0.2.6-py35h7eb728f_0',
#  'django-controlcenter-0.2.9-py_0',
#  'suspect-0.4.2-py38h32f6830_0',
#  'landlab-2.2.0-py38h347fdf6_1',
#  'cmreshandler-1.0.0-py37hc8dfbb8_1',
#  'deepforest-0.3.2-py36h0130604_0',
#  'point_cloud_utils-0.15.1-py38hd103949_2',
#  'andes-1.1.1-py37hc8dfbb8_0',
#  'jaws-1.0-py38h50d1736_2',
#  'yt_astro_analysis-1.0.0-py38hc8d92b1_1000',
#  'igl-2.2.1-py36he6478a9_1',
#  'jaws-0.7.7-py27_1',
#  'suspect-0.4.3-py37h89c1867_1',
#  'birdy-v0.6.6-py_0',
#  'intake-avro-0.2.0-py_0',
#  'point_cloud_utils-0.12.0-py27h9de70de_0',
#  'igl-0.4-py38h6dc7ae4_0',
#  'pystac-0.5.2-pyh9f0ad1d_0',
#  'pykafka-2.8.0-py27h36adfd1_1000',
#  'pycroscopy-0.60.4-py37_0',
#  'pykafka-2.8.0-py37h9daf859_1001',
#  'pfapack-0.2.1-py36hbe0be1c_1',
#  'point_cloud_utils-0.11.0-py27hbf1eeb5_1',
#  'pycroscopy-0.60.2-py37_1000',
#  'ghost.py-0.2.3-py36_0',
#  'suspect-0.3.9-py37_1001',
#  'point_cloud_utils-0.15.0-py36h049e832_2',
#  'cmreshandler-1.0.0-py37_0',
#  'plantcv-3.10.0-pyh9f0ad1d_0',
#  'landlab-2.1.0-py38h65ad66c_0',
#  'tomlkit-0.5.8-py36_0',
#  'ibm_db-3.0.1-py36h516909a_0',
#  'pyprojroot-0.1.2-py_0',
#  'bqplot-0.12.8-pyh9f0ad1d_0',
#  'pyrobuf-0.8.6-py27hf484d3e_0',
#  'benchmark-4dn-0.5.8-py_0',
#  'pymapd-0.24.1-py_0',
#  'igl-2.2.1-py37h109594f_0',
#  'verta-0.14.15-pyh9f0ad1d_0',
#  'birdy-v0.6.9-py_0',
#  'xsum-1.1.1-py36hdbb1a49_2',
#  'pykafka-2.8.0-py38h3663b88_1000',
#  'igl-2.2.0-py36h3552fb2_0',
#  'crystals-0.6.2-py_1',
#  'ukpopulation-1.2.2-pyhd3deb0d_0',
#  'pfapack-0.2.1-py38h8cc34b7_1',
#  'trio_asyncio-0.9.1-py36_1000',
#  'andes-1.0.8-py37hc8dfbb8_0',
#  'benchmark-4dn-0.5.12-py_0',
#  'atom-0.3.9-py27_0',
#  'point_cloud_utils-0.10.1-py36h9de70de_1',
#  'quilt3-3.1.7-py36_0',
#  'web.py-0.51-pyh9f0ad1d_0',
#  'mf2-2020.8.0-py_0',
#  'landlab-2.1.0-py38h8790de6_0',
#  'igl-0.4.1-py37h8bd51ef_0',
#  'neptune-client-0.4.101-py_0',
#  'pycroscopy-0.60.0-py35_0',
#  'pyathena-1.6.1-py37_0',
#  'andes-0.9.1-py36h9f0ad1d_0',
#  'moviepy-0.2.3.3-py27_0',
#  'glymur-0.9.2-pyhd8ed1ab_1',
#  'pfapack-0.2.1-py36ha15d459_2',
#  'andes-1.0.1-py38h32f6830_0',
#  'optuna-2.0.0-py_0',
#  'quickle-0.4.0-py38h1e8a9f7_0',
#  'pyathena-1.6.1-py27_0',
#  'point_cloud_utils-0.13.0-py37hbf1eeb5_1',
#  'pydeck-0.2.1-py_0',
#  'igl-0.4-py37hd0167a9_1',
#  'esmlab-2019.2.1-py_0',
#  'andes-0.9.1-py37hc8dfbb8_0',
#  'igl-2.2.1-py38hb3cf673_0',
#  'pfapack-0.2.1-py38haa244fe_2',
#  'jupyter_server-1.0.3-py38h32f6830_0',
#  'jaws-0.2.7-py_0',
#  'jaws-0.8.2-py27_0',
#  'compaction-0.2.1-py_0',
#  'andes-1.0.3-py36h9f0ad1d_0',
#  'igl-0.4-py37h8bd51ef_0',
#  'jaws-0.8.4-py37_0',
#  'awacs-0.9.9-pyh9f0ad1d_0',
#  'point_cloud_utils-0.13.0-py27hbf1eeb5_1',
#  'google-cloud-monitoring-0.24.0-py35_0',
#  'andes-1.2.0-py38h32f6830_0',
#  'igl-0.4.1-py38hd0167a9_0',
#  'markdown-it-py-0.4.3-py_0',
#  'pykafka-2.8.0-py35h372abb6_0',
#  'arosics-1.0.0-py38h32f6830_0',
#  'jaws-0.8.1-py27_0',
#  'jaws-0.7.7-py36_1',
#  'jaws-0.2.8-py_0',
#  'nr.types-3.0.3-py_0',
#  'pyusid-0.0.5-py36_0',
#  'neptune-client-0.4.118-pyh9f0ad1d_0',
#  'grayskull-0.8.3-py_0',
#  'grayskull-0.3.1-py_0',
#  'suspect-0.4.3-py36h5fab9bb_1',
#  'nr.types-3.1.0-py_0',
#  'chemex-2018.10.0-py_0',
#  'point_cloud_utils-0.12.2-py36h9de70de_0',
#  'theano-pymc-1.0.9-py36h831f99a_0',
#  'kim-property-2.3.0-py_1',
#  'bqplot-0.12.15-pyh9f0ad1d_0',
#  'theano-pymc-1.0.10-py37hf2a7229_0',
#  'awacs-0.9.8-py36h9f0ad1d_0',
#  'biom-format-2.1.6-py35h452e1ab_0',
#  'platformio-5.0.0-py_0',
#  'google-cloud-bigquery-0.24.0-py27_0',
#  'yt_astro_analysis-1.0.0-py27h470a237_0',
#  'point_cloud_utils-0.9.1-py36h96a391d_0',
#  'polyfempy-0.2-py37h6538335_0',
#  'trio_asyncio-0.11.0-py36hc560c46_2',
#  'pykafka-2.8.0-py36hfa6e2cd_1000',
#  'thredds_crawler-1.5.1-py34_0',
#  'aiida-core-1.2.0-py37hc8dfbb8_1',
#  'ibm_db-3.0.1-py36h01d97ff_0',
#  'cyberpandas-1.1.1-py35_0',
#  'chemex-2018.10.1-py_0',
#  'landlab-2.1.0-py36h7725771_0',
#  'tyssue-0.2rc2-3',
#  'jaws-0.5.3-py27_0',
#  'point_cloud_utils-0.15.1-py37h236b0a6_2',
#  'landlab-2.1.0-py38h40bdaab_0',
#  'point_cloud_utils-0.9.1-py27hbf1eeb5_0',
#  'grayskull-0.7.3-py_0',
#  'ibm_db-3.0.1-py37h01d97ff_1',
#  'verta-0.14.9-pyh9f0ad1d_0',
#  'verta-0.14.11-pyh9f0ad1d_0',
#  'optuna-1.0.0-py_0',
#  'nr.types-3.1.1-py_0',
#  'suspect-0.4.1-py38h32f6830_0',
#  'point_cloud_utils-0.9.1-py27h9de70de_0',
#  'andes-1.1.5-py37hc8dfbb8_0',
#  'py-tools-ds-0.15.6-py38h32f6830_1',
#  'clisops-0.3.1-py36h9f0ad1d_0',
#  'pybtex-0.23.0-py36hc560c46_0',
#  'pyrobuf-0.9.0-py27h172ad17_1',
#  'jaws-0.3.3-py35_2',
#  'tomlkit-0.6.0-py36h9f0ad1d_0',
#  'polyfempy-0.2.2-py36h6538335_0',
#  'landlab-2.0.0b7-py38h3b54f70_0',
#  'suspect-0.4.3-py36h9f0ad1d_0',
#  'jaws-1.0-py37h89c1867_2',
#  'pyusid-0.0.4-py36_1000',
#  'grayskull-0.1.8-py_0',
#  'baycomp-1.0.2-py_0',
#  'point_cloud_utils-0.12.0-py36h96a391d_0',
#  'aiida-core-1.1.1-py36_0',
#  'pykafka-2.8.0-py36h372abb6_0',
#  'neptune-client-0.4.110-pyh9f0ad1d_0',
#  'jaws-0.7.7-py36_0',
#  'verta-0.14.4-pyh9f0ad1d_0',
#  'tomlkit-0.5.11-py36hc560c46_1',
#  'verta-0.14.10-pyh9f0ad1d_0',
#  'pymapd-0.24.2-pyh050c7b8_3',
#  'pyrobuf-0.9.1-py38hb99c5c2_0',
#  'jaws-0.8.3-py36_1',
#  'emperor-1.0.0b19-py27_0',
#  'bamnostic-1.1.3-py_0',
#  'quilt3-3.1.6-py37_0',
#  'adversarial-robustness-toolbox-1.4.1-pyh9f0ad1d_0',
#  'pykafka-2.7.0-py27hc502c5b_0',
#  'quilt3-3.1.6-py36_0',
#  'tyssue-0.2.3-py36_2',
#  'fasttsne-0.2.13-py36h7eb728f_0',
#  'quilt3-3.1.12-py37hc8dfbb8_0',
#  'greedy-0.1.1-py_0',
#  'jaws-0.8.5-py37_0',
#  'kim-property-2.2.0-py_0',
#  'kim-edn-1.2.0-py_1',
#  'superset-0.33.0rc1-py36_0',
#  'quickle-0.1.0-py39h07f9747_1',
#  'andes-0.8.3-py38h32f6830_0',
#  'ibm_db-3.0.1-py36hfa6e2cd_0',
#  'xsum-1.1.1-py38h02bb52f_1',
#  'deepforest-0.2.19-py38h950e882_0',
#  'andes-0.8.1-py36_1',
#  'point_cloud_utils-0.12.0-py36hbf1eeb5_0',
#  'neptune-client-0.4.108-pyh9f0ad1d_0',
#  'pfapack-0.2.1-py39hcbf5309_2',
#  'arosics-0.9.23-pyh9f0ad1d_0',
#  'geoarray-0.9.2-py37hc8dfbb8_0',
#  'quickle-0.3.0-py38h4d0b108_0',
#  'point_cloud_utils-0.10.1-py27h9de70de_1',
#  'polyfempy-0.2-py36h0a44026_0',
#  'suds-jurko-0.6-py37hc8dfbb8_1002',
#  'pfapack-0.2.1-py38h32f6830_0',
#  'mf2-2020.4.3-py_0',
#  'andes-0.9.4-py38h32f6830_0',
#  'point_cloud_utils-0.13.0-py38h9de70de_1',
#  'intake-parquet-0.2.3-py_0',
#  'trio_asyncio-0.11.0-py37hc8dfbb8_1',
#  'saws-0.4.3-py36_0',
#  'cyberpandas-1.1.1-py39hde42818_1002',
#  'pyrobuf-0.9.3-py36h90709c0_1',
#  'kim_edn-1.0.0-py_0',
#  'tyssue-0.2.3-py37_1002',
#  'suspect-0.4.3-py36h79c6626_1',
#  'landlab-2.0.0b7-py37hc8d92b1_0',
#  'grayskull-0.8.1-py_0',
#  'point_cloud_utils-0.10.1-py38h9de70de_1',
#  'json5-0.8.5-py_0',
#  'igl-0.4.1-py38h53c40bd_1',
#  'polyfempy-0.2.1-py37hf484d3e_0',
#  'suds-jurko-0.6-py36_1',
#  'jaws-0.7.2-py37_0',
#  'igl-0.1-py27h7fc5cc3_0',
#  'sphinx-js-3.1-py_0',
#  'acorns-0.0.1-py36h863e41a_0',
#  'onnx-caffe2-1.0.0-py36_1000',
#  'andes-1.1.0-py36h9f0ad1d_0',
#  'xsum-1.1.1-py38hbf85e49_0',
#  'yt_astro_analysis-1.0.0-py37hc1659b7_1000',
#  'quickle-0.2.0-py39h07f9747_0',
#  'pydeck-0.3.0-pyh9f0ad1d_0',
#  'pydeck-0.4.1-pyh9f0ad1d_0',
#  'pfapack-0.2.1-py37hadd3336_0',
#  'trio-asyncio-0.11.0-py38h32f6830_2',
#  'andes-1.0.2-py38h32f6830_0',
#  'quilt3-3.1.9-py36_0',
#  'swagger-django-generator-0.0.3-py_0',
#  'jaws-0.7.6-py37_0',
#  'verta-0.14.17-pyh9f0ad1d_0',
#  'arosics-0.9.26-py38h32f6830_0',
#  'trio_asyncio-0.8.0-py36_0',
#  'verta-0.14.12-pyh9f0ad1d_0',
#  'otwrapy-0.7-py35_0',
#  'stitchm-1.0.3-py36hc560c46_1',
#  'jupyter_server-1.0.4-py38h32f6830_0',
#  'point_cloud_utils-0.13.0-py27hbf1eeb5_0',
#  'esmlab-2019.3.16-py_0',
#  'ibm_db-3.0.1-py37h516909a_1',
#  'stitchm-1.0.1-py38h32f6830_2',
#  'yt_astro_analysis-1.0.0-py36h8062767_1001',
#  'dexplot-0.1.4-py_0',
#  'pystac-0.5.0-pyh9f0ad1d_0',
#  'pfapack-0.1.1-py_0',
#  'suspect-0.4.3-py36hd000896_1',
#  'awacs-1.0.0-pyh9f0ad1d_0',
#  'deepforest-0.3.2-py37h3340039_1',
#  'point_cloud_utils-0.11.1-py37h96a391d_0',
#  'jaws-0.4.8-py36_0',
#  'quilt-3.0.6-py37_0',
#  'landlab-2.1.0-py37h44b1f71_0',
#  'point_cloud_utils-0.9.2-py36hbf1eeb5_0',
#  'flask-restless-1.0.0b1-py27_0',
#  'plonk-0.7.1-py_0',
#  'atlassian-python-api-1.17.1-pyh9f0ad1d_0',
#  'jsondate-0.1.2-py_0',
#  'bamnostic-1.1.2-py_0',
#  'scikit-time-0.1-py36hb3f55d8_0',
#  'stitchm-1.0.1-py36hc560c46_2',
#  'suspect-0.4.1-py37hc8dfbb8_0',
#  'pyusid-0.0.7-py37_0',
#  'awslogs-0.14.0-pyh9f0ad1d_0',
#  'point_cloud_utils-0.13.0-py36h6957fcd_2',
#  'intake-xarray-0.2.4-py_0',
#  'ipywebrtc-0.4.2-py27_1000',
#  'bamnostic-1.0.11-py_0',
#  'point_cloud_utils-0.9.1-py36h9de70de_0',
#  'tomlkit-0.5.7-py27_0',
#  'grayskull-0.7.2-py_0',
#  'jaws-0.4-py36_0',
#  'terrainbento-0.9.2-py_0',
#  'jupyter_telemetry-0.0.4-py_0',
#  'neptune-client-0.4.119-pyh9f0ad1d_0',
#  'optuna-1.2.0-py_0',
#  'pyrobuf-0.9.3-py38h7ae7562_1',
#  'landlab-2.2.0-py36h8062767_0',
#  'deepforest-0.2.19-py36h0130604_0',
#  'igl-0.5-py36h39f6697_0',
#  'pykafka-2.8.0-py36h89b1431_0',
#  'pykafka-2.8.0-py27h0c8e037_1000',
#  'pykafka-2.8.0-py37h9daf859_1002',
#  'jaws-0.6.5-py27_0',
#  'grayskull-0.4.1-py_0',
#  'yt_astro_analysis-1.0.0-py36h14c3975_1000',
#  'pyrobuf-0.8.7-py36h6de7cb9_0',
#  'igl-0.2-py36h3084ebe_0',
#  'point_cloud_utils-0.13.0-py37h9de70de_1',
#  'xcube_geodb-0.1.5-py_0',
#  'cyberpandas-1.1.1-py38h32f6830_1001',
#  'suspect-0.4.1-py36hc560c46_1',
#  'xsum-1.1.1-py39hdbc963e_2',
#  'point_cloud_utils-0.9.2-py38hbf1eeb5_0',
#  'andes-1.0.1-py37hc8dfbb8_1',
#  'jaws-0.8-py36_0',
#  'yt_astro_analysis-1.0.0-py36h3b54f70_1000',
#  'suds-jurko-0.6-py27_0',
#  'aiida-core-1.2.0-py36h9f0ad1d_0',
#  'igl-2.2.1-py36h1159412_0',
#  'point_cloud_utils-0.10.1-py36h96a391d_1',
#  'jaws-0.7.3-py37_0',
#  'suspect-0.4.3-py37h03978a9_1',
#  'awacs-0.9.8-py27h8c360ce_1',
#  'clisops-0.2.1-py38h32f6830_0',
#  'verta-0.14.8-pyh9f0ad1d_0',
#  'point_cloud_utils-0.13.0-py37h96a391d_1',
#  'igl-0.3-py36h3084ebe_0',
#  'pyrobuf-0.8.5-py37hf484d3e_1000',
#  'pydeck-0.4.0-pyh9f0ad1d_0',
#  'xsum-1.1.1-py36hadcdec8_1',
#  'quilt3-3.1.10-py37_0',
#  'geoarray-0.9.1-py37hc8dfbb8_0',
#  'wrighttools-3.0.1-py_0',
#  'pycroscopy-0.60.4-py27_0',
#  'otwrapy-0.9-pyh95af2a2_3',
#  'graspy-0.2-py_0',
#  'optuna-1.3.0-py_0',
#  'point_cloud_utils-0.16.0-py36hc79f972_0',
#  'llnl-sina-1.9.1-pyh9f0ad1d_0',
#  'point_cloud_utils-0.11.1-py37h9de70de_0',
#  'awslogs-0.13.0-pyh9f0ad1d_0',
#  'igl-2.2.0-py36h39f6697_0',
#  'bamnostic-0.8.5-py_0',
#  'landlab-2.0.0b4-py38hc1659b7_0',
#  'artificial-adversary-1.1-pyh9f0ad1d_0',
#  'trio-asyncio-0.11.0-py37hc8dfbb8_2',
#  'andes-0.8.5-py38h32f6830_0',
#  'landlab-2.2.0-py37ha21ca33_1',
#  'deepforest-0.3.2-py36h0130604_2',
#  'xclim-0.10.9b0-py_0',
#  'pyrobuf-0.8.7-py27he1b5a44_0',
#  'pybtex-0.22.2-py36hc560c46_1',
#  'jaws-0.8.4-py36_0',
#  'cyberpandas-1.0.0-py27_0',
#  'jaws-1.0-py36h79c6626_2',
#  'polygon-geohasher-0.0.1-py_0',
#  'theano-pymc-1.0.9-py36h27176af_0',
#  'ibm_db-3.0.2-py36h8c4c3a4_0',
#  'igl-0.1-py36h3084ebe_1',
#  'pymatsolver-0.1.2-py_0',
#  'geoarray-0.9.1-py38h32f6830_0',
#  'ibm_db-3.0.2-py37h4ab8f01_1',
#  'jaws-0.7.7-py37_0',
#  'arosics-0.9.24-py36h9f0ad1d_3',
#  'xsum-1.1.1-py36hadcdec8_0',
#  'pykafka-2.8.0-py38ha4d34e6_1001',
#  'point_cloud_utils-0.9.2-py38h96a391d_0',
#  'pfapack-0.2.1-py36h4adde33_0',
#  'pykafka-2.8.0-py27h372abb6_0',
#  'pybtex-0.22.2-py37hc8dfbb8_2',
#  'saws-0.4.3-py27_1',
#  'jaws-0.7.7-py37_2',
#  'tomlkit-0.6.0-py37hc8dfbb8_0',
#  'bar_chart_race-0.1.0-pyh9f0ad1d_0',
#  'stitchm-1.0.1-py36h9f0ad1d_1',
#  'awacs-0.9.8-pyh9f0ad1d_2',
#  'crystals-0.6.6-py_0',
#  'grayskull-0.2.2-py_0',
#  'pyrobuf-0.9.3-py36h90709c0_0',
#  'pyrobuf-0.9.0-py37he1b5a44_0',
#  'magpylib-1.2.0b0-py_0',
#  'pykafka-2.8.0-py36h3771aad_1001',
#  'django-controlcenter-0.2.5-py_0',
#  'django-versatileimagefield-1.7.1-py_1',
#  'jaws-0.7.5-py27_0',
#  'bqplot-0.12.3-py_0',
#  'glymur-0.9.2-py_0',
#  'landlab-2.1.1-py36h785e9b2_0',
#  'pystac-0.5.3-pyhd3deb0d_0',
#  'point_cloud_utils-0.10.1-py36hbf1eeb5_1',
#  'crystals-0.6.5-py_1',
#  'andes-0.8.3-py37hc8dfbb8_0',
#  'jaws-0.4.3-py36_0',
#  'aws-parallelcluster-2.4.1-py27_0',
#  'pfapack-0.2.1-py38h3666f18_0',
#  'andes-0.9.5-py37hc8dfbb8_0',
#  'point_cloud_utils-0.16.0-py36h1f35d00_0',
#  'andes-0.8.2-py38_0',
#  'igl-0.4-py37h6dc7ae4_0',
#  'pyusid-0.0.6-py27_0',
#  'pyrobuf-0.9.0-py36h90709c0_1',
#  'fasttsne-0.2.13-py37h917ab60_1',
#  'xsum-1.1.1-py39h45ac560_2',
#  'igl-0.4.1-py36h8bd51ef_0',
#  'quickle-0.4.0-py39h4cdbadb_0',
#  'igl-2.2.1-py36h115f05a_1',
#  'pykafka-2.8.0-py39ha3f4061_1002',
#  'ibm_db-3.0.2-py37h8f50634_1',
#  'bamnostic-1.0.10-py_0',
#  'pykafka-2.8.0-py38h1e8a9f7_1002',
#  'pytmc-2.6.0-py_1',
#  'polyfempy-0.2.1-py37h6538335_0',
#  'theano-pymc-1.0.10-py38hf416894_0',
#  'atlassian-python-api-1.17.5-pyh9f0ad1d_0',
#  'python-lambda-4dn-0.12.3-py_0',
#  'greedy-0.1.1-py_1',
#  'quickle-0.3.0-py38h1e8a9f7_0',
#  'pyrobuf-0.9.0-py38h950e882_1',
#  'igl-2.2.0-py38h5d0d19c_0',
#  'igl-2.2.1-py38h93ee5da_1',
#  'emperor-1.0.0b19-py36_0',
#  'landlab-2.1.0-py36h255dfe6_0',
#  'stateplane-0.3.1-py_0',
#  'nr.types-3.0.1-py_0',
#  'yt_astro_analysis-1.0.0-py37h3b54f70_1000',
#  'saws-0.4.3-py37_0',
#  'awacs-0.9.8-py38h32f6830_0',
#  'point_cloud_utils-0.10.1-py37h96a391d_1',
#  'andes-0.8.5-py36h9f0ad1d_0',
#  'bamnostic-0.8.11-py_0',
#  'xsum-1.1.1-py37h1fb7aa8_0',
#  'grayskull-0.2.3-py_0',
#  'jaws-0.7.3-py36_0',
#  'yodatools-0.2.0a0-py27_0',
#  'arosics-0.9.24-pyh9f0ad1d_0',
#  'fasttsne-0.2.7-py36h452e1ab_1',
#  'tyssue-0.2-0',
#  'pyrobuf-0.9.0-py38hc84c608_1',
#  'pyrobuf-0.9.3-py39ha36be7a_1',
#  'andes-0.9.2-py38h32f6830_0',
#  'point_cloud_utils-0.12.0-py38h9de70de_0',
#  'igl-0.2-py37h6dc7ae4_0',
#  'pyusid-0.0.6.3-py37_0',
#  'awacs-0.9.7-py27h8c360ce_0',
#  'andes-1.1.0-py38h32f6830_0',
#  'jaws-0.7.3-py27_0',
#  'yt_astro_analysis-1.0.0-py27h3b54f70_1000',
#  'point_cloud_utils-0.10.1-py36h96a391d_0',
#  'param_persist-0.1.3-pyhd8ed1ab_0',
#  'point_cloud_utils-0.13.0-py36h63ed162_2',
#  'landlab-2.0.0b3-py36hc1659b7_0',
#  'yt_astro_analysis-1.0.0-py36h68bb277_1001',
#  'ipywebrtc-0.4.1-py27_0',
#  'tranquilizer-0.4.1-py_0',
#  'trio-asyncio-0.11.0-py37hc8dfbb8_1',
#  'andes-1.0.6-py37hc8dfbb8_0',
#  'kim_property-1.0.1-py_0',
#  'stitchm-1.0.2-py37hc8dfbb8_0',
#  'point_cloud_utils-0.11.0-py37h9de70de_1',
#  'trio_asyncio-0.8.4-py36_0',
#  'point_cloud_utils-0.9.0-py27haf112f3_0',
#  'poster-0.8.1-py27_0',
#  'verta-0.14.2-pyh8c360ce_0',
#  'pyrobuf-0.8.6-py36hf484d3e_0',
#  'google-cloud-monitoring-0.24.0-py36_0',
#  'deepforest-0.3.0-py38h950e882_0',
#  'jupyter_server-1.0.4-py38h32f6830_1',
#  'astroid-2.4.0-py36h9f0ad1d_0',
#  'yt_astro_analysis-1.0.0-py27hc1659b7_1000',
#  'pykafka-2.8.0-py37hba13f1d_1000',
#  'otwrapy-0.7-py27_0',
#  'onnx-caffe2-1.0.0-py27_1000',
#  'igl-0.4.1-py38h8bd51ef_0',
#  'trio_asyncio-0.11.0-py38h32f6830_1',
#  'scikit-time-0.1-py38hb3f55d8_0',
#  'tomlkit-0.7.0-py36h9f0ad1d_1',
#  'pyrobuf-0.9.0-py37h4a8c4bd_0',
#  'tomlkit-0.7.0-py36h9f0ad1d_0',
#  'tomlkit-0.5.11-py27h8c360ce_1',
#  'magpylib-2.1.0b0-py_0',
#  'quilt-3.0.5-py36_0',
#  'andes-0.9.2-py37hc8dfbb8_0',
#  'grayskull-0.1.9-py_0',
#  'quickle-0.3.0-py38h1e0a361_0',
#  'pyrobuf-0.8.5-py36hf484d3e_1000',
#  'landlab-2.0.0b3-py37h3b54f70_0',
#  'trio_asyncio-0.11.0-py37hc8dfbb8_2',
#  'suspect-0.3.9-py37_1000',
#  'graypy-1.1.3-py_0',
#  'emperor-1.0.0-py37_0',
#  'andes-1.1.4-py37hc8dfbb8_0',
#  'igl-0.2-py37h3084ebe_0',
#  'igl-0.1-py37h7fc5cc3_0',
#  'plantcv-3.10.1-pyh9f0ad1d_0',
#  'awacs-0.9.7-py37hc8dfbb8_0',
#  'clisops-0.3.0-py38h32f6830_0',
#  'optuna-2.1.0-py_0',
#  'cyberpandas-1.1.1-py27_1000',
#  'qme-0.0.12-py_0',
#  'suds-jurko-0.6-py38h32f6830_1002',
#  'emperor-1.0.1-py39h6e9494a_1',
#  'point_cloud_utils-0.13.0-py36h96a391d_0',
#  'quilt3-3.1.5-py36_0',
#  'optuna-0.19.0-py_0',
#  'point_cloud_utils-0.9.2-py27h9de70de_0',
#  'quilt3-3.1.14-pyh9f0ad1d_1',
#  'point_cloud_utils-0.12.0-py36h9de70de_0',
#  'point_cloud_utils-0.15.0-py36h6957fcd_2',
#  'suds-jurko-0.6-py27h8c360ce_1002',
#  'sphinx-js-3.0-pyh9f0ad1d_0',
#  'xcube_geodb-0.1.9-py_2',
#  'acorns-0.0.1-py38ha0d09dd_0',
#  'andes-1.0.5-py36h9f0ad1d_0',
#  'awacs-0.9.6-py38_0',
#  'jaws-0.6.4-py27_0',
#  'moviepy-0.2.3.2-py36_0',
#  'moviepy-0.2.3.2-py27_0',
#  'pydeck-0.3.1-pyh9f0ad1d_0',
#  'igl-0.4.1-py36hb1c73a4_1',
#  'pybtex-0.23.0-py37hc8dfbb8_0',
#  'jaws-0.7.6-py27_0',
#  'pytmc-2.6.8-py_0',
#  'trio-aiohttp-0.2.3-py_0',
#  'cyberpandas-1.1.1-py37_1000',
#  'bamnostic-0.8.9-py_0',
#  'xcube_geodb-0.1.6-py_0',
#  'point_cloud_utils-0.11.0-py36h96a391d_0',
#  'pyomeca-1.0.1-pyh9f0ad1d_0',
#  'xsum-1.1.1-py38h95a2b95_1',
#  'pyrobuf-0.9.3-py37h63f7a3c_0',
#  'jaws-0.5.2-py36_0',
#  'jaws-0.8.2-py37_0',
#  'ghost.py-0.2.3-py_1',
#  'trio-asyncio-0.11.0-py36h9f0ad1d_0',
#  'pyrobuf-0.8.6-py27h0a44026_0',
#  'bamnostic-1.0.3-py_0',
#  'point_cloud_utils-0.10.1-py38h96a391d_1',
#  'chemex-2018.9.2-py_0',
#  'globus-cli-1.1.2-py_0',
#  'fasttsne-0.2.10-py36h452e1ab_0',
#  'landlab-2.0.0b6-py37h3b54f70_0',
#  'landlab-2.0.0b6-py37hc1659b7_0',
#  'fasttsne-0.2.13-py37h3010b51_1',
#  'emperor-1.0.0b20-py36_0',
#  'pfapack-0.2.1-py36hc4c5385_1',
#  'trio-asyncio-0.11.0-py37hc8dfbb8_0',
#  'thredds_crawler-1.5.0-py35_0',
#  'polyfempy-0.2.2-py37h0a44026_0',
#  'jaws-0.7-py27_0',
#  'suspect-0.4.2-py36h9f0ad1d_0',
#  'pyrobuf-0.9.3-py37h3340039_1',
#  'graypy-1.1.1-py_0',
#  'point_cloud_utils-0.13.0-py37h9de70de_0',
#  'igl-0.4.1-py37hf531a45_1',
#  'fasttsne-0.2.6-py36h7eb728f_0',
#  'theano-pymc-1.0.10-py36he2d232f_0',
#  'andes-1.0.7-py36h9f0ad1d_0',
#  'arosics-0.9.25-py36h9f0ad1d_0',
#  'pyrobuf-0.9.3-py36hbd05846_0',
#  'point_cloud_utils-0.10.1-py37h9de70de_0',
#  'point_cloud_utils-0.8.4-py27h9de70de_0',
#  'tinydb-3.2.0-py36_1',
#  'suspect-0.3.9-py36_1000',
#  'pykafka-2.8.0-py36hfa6e2cd_0',
#  'pymapd-0.17.0-py_0',
#  'pyusid-0.0.4-py37_1000',
#  'esmlab-2019.2.28-py_0',
#  'acorns-0.0.1-py37ha1cc60f_0',
#  'jaws-0.4.1-py35_0',
#  'scikit-lego-0.6.0-py_0',
#  'andes-1.0.7-py37hc8dfbb8_0',
#  'point_cloud_utils-0.15.0-py37h236b0a6_2',
#  'jaws-0.7.2-py27_0',
#  'optuna-2.0.0-py_1',
#  'point_cloud_utils-0.11.0-py36h96a391d_1',
#  'aiida-core-1.2.1-py37hc8dfbb8_0',
#  'jaws-1.0-py39hf3d152e_2',
#  'nr.types-3.0.2-py_0',
#  'point_cloud_utils-0.11.1-py27hbf1eeb5_0',
#  'xsum-1.1.1-py36h1cd168d_2',
#  'tomlkit-0.5.11-py37hc8dfbb8_1',
#  'andes-1.0.0-py38h32f6830_0',
#  'landlab-2.0.0b4-py37h3b54f70_0',
#  'jaws-1.0-py37h03978a9_2',
#  'typhos-1.0.1-py_0',
#  'markov_draftjs-0.1.1-py_0',
#  'pykafka-2.8.0-py36h643eda9_1002',
#  'pykafka-2.8.0-py38h40d68c1_1000',
#  'jaws-1.0-py36h5fab9bb_2',
#  'eventkit-0.8.5-py_0',
#  'jaws-0.9-py36_0',
#  'trio_asyncio-0.11.0-py39hde42818_2',
#  'atlassian-python-api-1.17.7-pyhd8ed1ab_0',
#  'igl-2.2.1-py36h556cf29_0',
#  'pfapack-0.2.1-py36h4adde33_1',
#  'pykafka-2.8.0-py36h3663b88_1000',
#  'point_cloud_utils-0.13.0-py37hbf1eeb5_0',
#  'jaws-0.8.3-py37_0',
#  'pyrobuf-0.9.0-py36h831f99a_1',
#  'emperor-1.0.1-py39hf3d152e_1',
#  'cyberpandas-1.1.1-py36_0',
#  'theano-pymc-1.0.7-py36h003fed8_0',
#  'landlab-2.2.0-py37h161383b_0',
#  'igl-2.2.0-py36hed50801_0',
#  'otwrapy-0.9-pyhac0dd68_4',
#  'jaws-0.5.3-py36_0',
#  'neptune-client-0.4.105-py_0',
#  'privy-6.0.0-py_0',
#  'point_cloud_utils-0.10.1-py38h96a391d_0',
#  'igl-2.2.1-py36hb1d0094_0',
#  'point_cloud_utils-0.12.0-py37hbf1eeb5_0',
#  'aws-parallelcluster-2.3.2a1-py37_1',
#  'grayskull-0.8.0-py_0',
#  'crystals-1.1.0-py_0',
#  'igl-0.4.1-py36hd0167a9_0',
#  'neptune-client-0.4.125-pyh9f0ad1d_0',
#  'onnx-caffe2-1.0.0-py36h9f0ad1d_1002',
#  'graypy-2.1.0-py_0',
#  'jaws-0.5.3-py36_1000',
#  'pyls-memestra-0.0.5-py_0',
#  'onnx-caffe2-1.0.0-py35_0',
#  'jaws-0.6.3-py36_0',
#  'ibm_db-3.0.1-py37hfa6e2cd_1',
#  'landlab-2.0.0b6-py36hc8d92b1_0',
#  'stitchm-1.0.3-py36hc560c46_0',
#  'graypy-1.1.2-py_0',
#  'intake-esm-2019.2.28-py_1',
#  'igl-0.3.1-py36h8bd51ef_0',
#  'polyfempy-0.2.2-py37hf484d3e_0',
#  'pyusid-0.0.6.3-py38_0',
#  'aiomysql-0.0.9-py36_0',
#  'docker-map-1.0.0-py_0',
#  'pfapack-0.2.1-py36h80301fe_2',
#  'polyfempy-0.2-py37hf484d3e_1',
#  'point_cloud_utils-0.15.0-py36h1f35d00_2',
#  'pymatsolver-0.1.2-py_1',
#  'ffx-1.3.4-py27_0',
#  'moviepy-0.2.3.3-py36_0',
#  'jupyter_server-1.0.5-py38h32f6830_0',
#  'jaws-0.4.7-py35_0',
#  'jaws-0.7.4-py37_0',
#  'pyathena-1.6.1-py36_0',
#  'ibm_db-3.0.1-py36hfa6e2cd_1',
#  'geoarray-0.8.37-py36h9f0ad1d_0',
#  'autouri-0.2.3-py_0',
#  'geoarray-0.8.35-py38h32f6830_0',
#  'scikit-lego-0.4.2-py_0',
#  'grayskull-0.1.6-py_0',
#  'tomlkit-0.5.11-py27_0',
#  'aws-parallelcluster-2.4.0-py37_0',
#  'landlab-2.1.1-py38h65ad66c_0',
#  'pyrobuf-0.9.3-py38hc84c608_0',
#  'stitchm-1.0.3-py37hc8dfbb8_0',
#  'pfapack-0.2.1-py39hb4a8f42_2',
#  'crystals-0.6.4-py_0',
#  'tyssue-0.2.2-py36_0',
#  'jaws-0.8.5-py27_0',
#  'jaws-0.4-py27_0',
#  'jaws-0.8-py27_0',
#  'aiida-core-1.2.1-py37hc8dfbb8_2',
#  'jupyterlab-git-0.5.0-py_1',
#  'point_cloud_utils-0.15.1-py37h429e714_2',
#  'ipywebrtc-0.4.0-py36_1',
#  'jaws-0.8.1-py37_0',
#  'igl-0.1-py36h8d973e4_0',
#  'moviepy-0.2.3.5-py_0',
#  'landlab-2.2.0-py37h7ff7679_1',
#  'deepforest-0.3.0-py37h570ac47_0',
#  'point_cloud_utils-0.9.2-py37h9de70de_0',
#  'xcube_geodb-0.1.9-py_1',
#  'yarg-0.1.9-py27_0',
#  'pyrobuf-0.9.1-py36h831f99a_0',
#  'landlab-2.0.0b7-py36hc1659b7_0',
#  'point_cloud_utils-0.12.1-py36h9de70de_0',
#  'pybtex-0.22.0-py37_1000',
#  'grayskull-0.5.0-py_0',
#  'xsum-1.1.1-py37h1fb7aa8_2',
#  'xsum-1.1.1-py36hdb11119_0',
#  'jaws-0.9.1-py27_0',
#  'ibm_db-3.0.2-py36h8c4c3a4_1',
#  'birdy-v0.6.7-py_0',
#  'point_cloud_utils-0.9.0-py36h9de70de_0',
#  'quilt3-3.1.10-py36_0',
#  'verta-0.14.13-pyh9f0ad1d_0',
#  'pyusid-0.0.5-py27_0',
#  'cyberpandas-1.1.1-py36h9f0ad1d_1002',
#  'emperor-1.0.1-py36h5fab9bb_1',
#  'stuf-0.9.16-py_0',
#  'igl-0.5-py38h5d0d19c_0',
#  'xclim-0.11.2-py_0',
#  'point_cloud_utils-0.9.2-py37h96a391d_0',
#  'theano-pymc-1.0.10-py36hdce0c9c_0',
#  'quickle-0.2.0-py38h1e8a9f7_0',
#  'bqplot-0.12.1-py_0',
#  'superset-0.34.0rc2-py37_0',
#  'deepforest-0.3.2-py37h570ac47_1',
#  'jaws-1.0-py36ha15d459_2',
#  'yt_astro_analysis-1.0.0-py37h14c3975_1000',
#  'pyusid-0.0.4-py36_0',
#  'onnx-caffe2-1.0.0-py37hc8dfbb8_1002',
#  'ipywebrtc-0.4.1-py36_1001',
#  'mleap-0.16.1-pyh9f0ad1d_0',
#  'andes-1.1.5-py38h32f6830_0',
#  'stitchm-1.0.3-py38h32f6830_0',
#  'ipywebrtc-0.4.0-py35_2',
#  'xsum-1.1.1-py36hdbb1a49_1',
#  'landlab-2.0.0b3-py36h3b54f70_0',
#  'jaws-0.7.1-py36_0',
#  'otwrapy-0.7-py36_1',
#  'jaws-0.9.3-py27_0',
#  'andes-1.0.1-py37hc8dfbb8_0',
#  'polyfempy-0.2.1-py36h6538335_1',
#  'igl-2.2.0-py37h41f50ff_0',
#  'neptune-client-0.4.103-py_0',
#  'pykafka-2.8.0-py27h40d68c1_1000',
#  'pykafka-2.8.0-py27h0c8e037_0',
#  'point_cloud_utils-0.11.0-py27h9de70de_0',
#  'pymapd-0.18.0-py_0',
#  'polyfempy-0.2-py36h6538335_0',
#  'landlab-2.0.1-py36h7725771_0',
#  'intake-parquet-0.2.1-py_0',
#  'igl-0.3.1-py38hd0167a9_0',
#  'igl-0.4-py38h6dc7ae4_1',
#  'xsum-1.1.1-py36hdbb1a49_0',
#  'suds-jurko-0.6-py36_1001',
#  'landlab-2.0.0b6-py36h3b54f70_0',
#  'pykafka-2.8.0-py38h1e8a9f7_1001',
#  'theano-pymc-1.0.10-py37h745909e_0',
#  'quilt3-3.1.14-py37hc8dfbb8_0',
#  'ibm_db-3.0.2-py37h9bfed18_1',
#  'igl-0.4-py36h8bd51ef_0',
#  'jaws-1.0-py37_0',
#  'biom-format-2.1.6-py36h7eb728f_0',
#  'landlab-2.0.1-py37h10e2902_0',
#  'pyrobuf-0.9.0-py37h3340039_1',
#  'bqplot-0.12.6-pyh8c360ce_0',
#  'otwrapy-0.9-pyh752d9f6_1',
#  'pykafka-2.8.0-py35hfa6e2cd_0',
#  'biom-format-2.1.6-py27h7eb728f_0',
#  ...}
