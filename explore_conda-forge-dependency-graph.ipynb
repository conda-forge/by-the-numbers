# %% [markdown]
# # Exploring the conda-forge Dependency Graph
#
# Conda forge keeps metadata about package dependencies in a JSON file on Github.  It's easy to download and manipulate this data.

# %%
def embed_graph(g):
    from IPython.display import HTML

    fname = "index.html"
    g.write_html(fname)
    with open(fname) as f:
        html = f.read()

    iframe = '<iframe srcdoc="{srcdoc}" style="width: 100%; height: 750px; border: none"></iframe>'
    srcdoc = html.replace('"', "&quot;")
    return HTML(iframe.format(srcdoc=srcdoc))

# %%
from pathlib import Path

path = Path(".")
if not path.joinpath("conda-forge.json").is_file():
    # !wget https://github.com/regro/libcfgraph/raw/master/conda-forge.json

# %%
import json

import networkx as nx

with open("conda-forge.json") as f:
    data = json.load(f)
    graph = nx.json_graph.node_link_graph(data)

# %%
from pyvis.network import Network


package = "pandas"
dependencies = nx.bfs_tree(graph, package, reverse=True)
dependants = nx.bfs_tree(graph, package, reverse=False)

# %%
g = Network(notebook=True)
g.from_nx(dependencies)

embed_graph(g)
# Out:
# /home/filipe/miniconda3/envs/CF-NUMBERS/lib/python3.8/site-packages/IPython/core/display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc="<html>
# <head>
# <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis.css&quot; type=&quot;text/css&quot; />
# <script type=&quot;text/javascript&quot; src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis-network.min.js&quot;> </script>
#
# <!-- <link rel=&quot;stylesheet&quot; href=&quot;../node_modules/vis/dist/vis.min.css&quot; type=&quot;text/css&quot; />
# <script type=&quot;text/javascript&quot; src=&quot;../node_modules/vis/dist/vis.js&quot;> </script>-->
#
# <style type=&quot;text/css&quot;>
#
#         #mynetwork {
#             width: 500px;
#             height: 500px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = &quot;mynetwork&quot;></div>
#
#
# <script type=&quot;text/javascript&quot;>
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{&quot;id&quot;: &quot;pandas&quot;, &quot;label&quot;: &quot;pandas&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;pandas&quot;}, {&quot;id&quot;: &quot;openssl&quot;, &quot;label&quot;: &quot;openssl&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;openssl&quot;}, {&quot;id&quot;: &quot;wheel&quot;, &quot;label&quot;: &quot;wheel&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;wheel&quot;}, {&quot;id&quot;: &quot;setuptools&quot;, &quot;label&quot;: &quot;setuptools&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;setuptools&quot;}, {&quot;id&quot;: &quot;python-dateutil&quot;, &quot;label&quot;: &quot;python-dateutil&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;python-dateutil&quot;}, {&quot;id&quot;: &quot;sqlite&quot;, &quot;label&quot;: &quot;sqlite&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;sqlite&quot;}, {&quot;id&quot;: &quot;ncurses&quot;, &quot;label&quot;: &quot;ncurses&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;ncurses&quot;}, {&quot;id&quot;: &quot;readline&quot;, &quot;label&quot;: &quot;readline&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;readline&quot;}, {&quot;id&quot;: &quot;libffi&quot;, &quot;label&quot;: &quot;libffi&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;libffi&quot;}, {&quot;id&quot;: &quot;python&quot;, &quot;label&quot;: &quot;python&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;python&quot;}, {&quot;id&quot;: &quot;libstdcxx-ng&quot;, &quot;label&quot;: &quot;libstdcxx-ng&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;libstdcxx-ng&quot;}, {&quot;id&quot;: &quot;certifi&quot;, &quot;label&quot;: &quot;certifi&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;certifi&quot;}, {&quot;id&quot;: &quot;ca-certificates&quot;, &quot;label&quot;: &quot;ca-certificates&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;ca-certificates&quot;}, {&quot;id&quot;: &quot;tk&quot;, &quot;label&quot;: &quot;tk&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;tk&quot;}, {&quot;id&quot;: &quot;pip&quot;, &quot;label&quot;: &quot;pip&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;pip&quot;}, {&quot;id&quot;: &quot;libgcc-ng&quot;, &quot;label&quot;: &quot;libgcc-ng&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;libgcc-ng&quot;}, {&quot;id&quot;: &quot;zlib&quot;, &quot;label&quot;: &quot;zlib&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;zlib&quot;}, {&quot;id&quot;: &quot;xz&quot;, &quot;label&quot;: &quot;xz&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;xz&quot;}, {&quot;id&quot;: &quot;numpy&quot;, &quot;label&quot;: &quot;numpy&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;numpy&quot;}, {&quot;id&quot;: &quot;openblas&quot;, &quot;label&quot;: &quot;openblas&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;openblas&quot;}, {&quot;id&quot;: &quot;cython&quot;, &quot;label&quot;: &quot;cython&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;cython&quot;}, {&quot;id&quot;: &quot;blas&quot;, &quot;label&quot;: &quot;blas&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;blas&quot;}, {&quot;id&quot;: &quot;toolchain&quot;, &quot;label&quot;: &quot;toolchain&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;toolchain&quot;}, {&quot;id&quot;: &quot;toolchain_c_linux-64&quot;, &quot;label&quot;: &quot;toolchain_c_linux-64&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;toolchain_c_linux-64&quot;}, {&quot;id&quot;: &quot;libgfortran&quot;, &quot;label&quot;: &quot;libgfortran&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;libgfortran&quot;}, {&quot;id&quot;: &quot;toolchain_cxx_l ...

# %%
g = Network(notebook=True)
g.from_nx(dependants)

embed_graph(g)
# Out:
# <iframe srcdoc="<html>
# <head>
# <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis.css&quot; type=&quot;text/css&quot; />
# <script type=&quot;text/javascript&quot; src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis/4.16.1/vis-network.min.js&quot;> </script>
#
# <!-- <link rel=&quot;stylesheet&quot; href=&quot;../node_modules/vis/dist/vis.min.css&quot; type=&quot;text/css&quot; />
# <script type=&quot;text/javascript&quot; src=&quot;../node_modules/vis/dist/vis.js&quot;> </script>-->
#
# <style type=&quot;text/css&quot;>
#
#         #mynetwork {
#             width: 500px;
#             height: 500px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#         #loadingBar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width: 500px;
#             height: 500px;
#             background-color:rgba(200,200,200,0.8);
#             -webkit-transition: all 0.5s ease;
#             -moz-transition: all 0.5s ease;
#             -ms-transition: all 0.5s ease;
#             -o-transition: all 0.5s ease;
#             transition: all 0.5s ease;
#             opacity:1;
#         }
#
#         #bar {
#             position:absolute;
#             top:0px;
#             left:0px;
#             width:20px;
#             height:20px;
#             margin:auto auto auto auto;
#             border-radius:11px;
#             border:2px solid rgba(30,30,30,0.05);
#             background: rgb(0, 173, 246); /* Old browsers */
#             box-shadow: 2px 0px 4px rgba(0,0,0,0.4);
#         }
#
#         #border {
#             position:absolute;
#             top:10px;
#             left:10px;
#             width:500px;
#             height:23px;
#             margin:auto auto auto auto;
#             box-shadow: 0px 0px 4px rgba(0,0,0,0.2);
#             border-radius:10px;
#         }
#
#         #text {
#             position:absolute;
#             top:8px;
#             left:530px;
#             width:30px;
#             height:50px;
#             margin:auto auto auto auto;
#             font-size:22px;
#             color: #000000;
#         }
#
#         div.outerBorder {
#             position:relative;
#             top:400px;
#             width:600px;
#             height:44px;
#             margin:auto auto auto auto;
#             border:8px solid rgba(0,0,0,0.1);
#             background: rgb(252,252,252); /* Old browsers */
#             background: -moz-linear-gradient(top,  rgba(252,252,252,1) 0%, rgba(237,237,237,1) 100%); /* FF3.6+ */
#             background: -webkit-gradient(linear, left top, left bottom, color-stop(0%,rgba(252,252,252,1)), color-stop(100%,rgba(237,237,237,1))); /* Chrome,Safari4+ */
#             background: -webkit-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Chrome10+,Safari5.1+ */
#             background: -o-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* Opera 11.10+ */
#             background: -ms-linear-gradient(top,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* IE10+ */
#             background: linear-gradient(to bottom,  rgba(252,252,252,1) 0%,rgba(237,237,237,1) 100%); /* W3C */
#             filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcfcfc', endColorstr='#ededed',GradientType=0 ); /* IE6-9 */
#             border-radius:72px;
#             box-shadow: 0px 0px 10px rgba(0,0,0,0.2);
#         }
#
#
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = &quot;mynetwork&quot;></div>
#
# <div id=&quot;loadingBar&quot;>
#     <div class=&quot;outerBorder&quot;>
#         <div id=&quot;text&quot;>0%</div>
#         <div id=&quot;border&quot;>
#             <div id=&quot;bar&quot;></div>
#         </div>
#     </div>
# </div>
#
#
# <script type=&quot;text/javascript&quot;>
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{&quot;id&quot;: &quot;pandas&quot;, &quot;label&quot;: &quot;pandas&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;pandas&quot;}, {&quot;id&quot;: &quot;airflow&quot;, &quot;label&quot;: &quot;airflow&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;airflow&quot;}, {&quot;id&quot;: &quot;alpenglow&quot;, &quot;label&quot;: &quot;alpenglow&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;alpenglow&quot;}, {&quot;id&quot;: &quot;alphalens&quot;, &quot;label&quot;: &quot;alphalens&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;alphalens&quot;}, {&quot;id&quot;: &quot;altair&quot;, &quot;label&quot;: &quot;altair&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;altair&quot;}, {&quot;id&quot;: &quot;amptools&quot;, &quot;label&quot;: &quot;amptools&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;amptools&quot;}, {&quot;id&quot;: &quot;aospy&quot;, &quot;label&quot;: &quot;aospy&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;aospy&quot;}, {&quot;id&quot;: &quot;asammdf&quot;, &quot;label&quot;: &quot;asammdf&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;asammdf&quot;}, {&quot;id&quot;: &quot;astrocats&quot;, &quot;label&quot;: &quot;astrocats&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;astrocats&quot;}, {&quot;id&quot;: &quot;axelrod&quot;, &quot;label&quot;: &quot;axelrod&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;axelrod&quot;}, {&quot;id&quot;: &quot;axopy&quot;, &quot;label&quot;: &quot;axopy&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;axopy&quot;}, {&quot;id&quot;: &quot;batman&quot;, &quot;label&quot;: &quot;batman&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;batman&quot;}, {&quot;id&quot;: &quot;bcolz&quot;, &quot;label&quot;: &quot;bcolz&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bcolz&quot;}, {&quot;id&quot;: &quot;beakerx&quot;, &quot;label&quot;: &quot;beakerx&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;beakerx&quot;}, {&quot;id&quot;: &quot;bgen-reader&quot;, &quot;label&quot;: &quot;bgen-reader&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bgen-reader&quot;}, {&quot;id&quot;: &quot;bgen_reader&quot;, &quot;label&quot;: &quot;bgen_reader&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bgen_reader&quot;}, {&quot;id&quot;: &quot;bilby&quot;, &quot;label&quot;: &quot;bilby&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bilby&quot;}, {&quot;id&quot;: &quot;billingegroup&quot;, &quot;label&quot;: &quot;billingegroup&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;billingegroup&quot;}, {&quot;id&quot;: &quot;biom-format&quot;, &quot;label&quot;: &quot;biom-format&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;biom-format&quot;}, {&quot;id&quot;: &quot;biopandas&quot;, &quot;label&quot;: &quot;biopandas&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;biopandas&quot;}, {&quot;id&quot;: &quot;bkcharts&quot;, &quot;label&quot;: &quot;bkcharts&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bkcharts&quot;}, {&quot;id&quot;: &quot;blaze&quot;, &quot;label&quot;: &quot;blaze&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;blaze&quot;}, {&quot;id&quot;: &quot;bootstrap_contrast&quot;, &quot;label&quot;: &quot;bootstrap_contrast&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bootstrap_contrast&quot;}, {&quot;id&quot;: &quot;bqplot&quot;, &quot;label&quot;: &quot;bqplot&quot;, &quot;shape&quot;: &quot;dot&quot;, &quot;title&quot;: &quot;bq
